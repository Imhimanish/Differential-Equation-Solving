# %% [markdown]
# <a href="https://colab.research.google.com/github/Imhimanish/Differential-Equation-Solving/blob/main/GithubCodes1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Euler’s method for Solution of Differential Equation

# %%
import matplotlib.pyplot as plt
import numpy as np
xx=[0]
yy=[1]
a=0
b=5
n=int(input("Enter the no. of terms = "))
y0 = 1
x0 = 0
h=(b-a)/n
while h<=5:

  x=h
  xx.append(x)
  y1 = y0 + ((b-a)/n) *(-y0)
  yy.append(y1)
  y0=y1
  h+=(b-a)/n

x1=[]
y1=[]
h=0
for i in xx:
  y=np.exp(-i)
  y1.append(y)
plt.figure(figsize=(16,10))
plt.plot(xx,y1, 'g',label = "Original")
plt.plot(xx,yy,'--r', label = "Calculated")
plt.legend(loc="best")
plt.title('The graph of E^-x Vs dy/dx = -y')
plt.xlabel("Value of x",size = 20)
plt.ylabel("Function", size = 20)
plt.show()
# Out:
# Enter the no. of terms = 10

# %% [markdown]
# also there is a result for 20 terms

# %% [markdown]
# ![Screenshot (13).png](data:image/png;base64,...)
